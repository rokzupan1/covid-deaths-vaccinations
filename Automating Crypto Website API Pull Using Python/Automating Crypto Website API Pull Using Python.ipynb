# %%
#This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '4f1dc377-a014-4588-96ac-ba7d3d03fc01',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2023-03-02T17:16:13.192Z', 'error_code': 0, 'error_message': None, 'elapsed': 19, 'credit_count': 1, 'notice': None, 'total_count': 8998}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 9995, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'btc-ecosystem'], 'max_supply': 21000000, 'circulating_supply': 19306187, 'total_supply': 19306187, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-03-02T17:13:00.000Z', 'quote': {'USD': {'price': 23285.847171549598, 'volume_24h': 21036862573.73189, 'volume_change_24h': -16.252, 'percent_change_1h': -0.36302724, 'percent_change_24h': -1.86524182, 'percent_change_7d': -2.32882626, 'percent_change_30d': 0.73381747, 'percent_change_60d': 40.49455867, 'percent_change_90d': 37.2724041, 'market_cap': 449560919947.3576, 'market_cap_dominance': 42.377, 'fully_diluted_market_cap': 489002790602.54, 'tvl': None, 'last_updated': '2023-03-02T17:13:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 6516, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem'], 'max_supply': None, 'circulating_supply': 122373866.2178, 'total_supply': 122373866.2178, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-03-02T17:13:00.000Z', 'quote': {'USD': {'price': 1625.3811346327377, 'volume_24h': 7034795946.741712, 'volume_change_24h': -12.6222, 'percent_change_1h': -0.21209867, 'percent_change_24h': -1.93701565, 'percent_change_7d': -1.59811778, 'percent_change_30d': 2.11211167, 'percent_change_60d': 35.70200252, 'percent_change_90d': 26.84961775, 'market_cap': 198904173522.48264, 'market_cap_dominance': 18.7493, 'fully_diluted_market_cap': 198904173522.48, 'tvl': None, 'last_updated': '2023-03-02T17:13:00.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 48675, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['payments', 'stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem'], 'max_supply': None, 'circulating_supply': 71062808809.48134, 'total_supply': 73141766321.23428, 'platform': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'token_address': '0xdac17f958d2ee523a2206206994597c ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd
#pd.set_option('display.max_columns', None)

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
# C:\Users\rokzu\AppData\Local\Temp\ipykernel_2596\644439384.py:2: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp'] = pd.to_datetime('now')
#       id         name symbol          slug  num_market_pairs  \
# 0      1      Bitcoin    BTC       bitcoin              9995
# 1   1027     Ethereum    ETH      ethereum              6516
# 2    825       Tether   USDT        tether             48675
# 3   1839          BNB    BNB           bnb              1204
# 4   3408     USD Coin   USDC      usd-coin             10413
# 5     52          XRP    XRP           xrp               897
# 6   2010      Cardano    ADA       cardano               660
# 7     74     Dogecoin   DOGE      dogecoin               649
# 8   3890      Polygon  MATIC       polygon               596
# 9   4687  Binance USD   BUSD   binance-usd              6337
# 10  5426       Solana    SOL        solana               436
# 11  6636     Polkadot    DOT  polkadot-new               475
# 12     2     Litecoin    LTC      litecoin               880
# 13  5994    Shiba Inu   SHIB     shiba-inu               490
# 14  1958         TRON    TRX          tron               731
#
#                   date_added  \
# 0   2013-04-28T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2018-10-08T00:00:00.000Z
# 5   2013-08-04T00:00:00.000Z
# 6   2017-10-01T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2019-04-28T00:00:00.000Z
# 9   2019-09-20T00:00:00.000Z
# 10  2020-04-10T00:00:00.000Z
# 11  2020-08-19T00:00:00.000Z
# 12  2013-04-28T00:00:00.000Z
# 13  2020-08-01T00:00:00.000Z
# 14  2017-09-13T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 5   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 6   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 7   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 8   [platform, enterprise-solutions, zero-knowledg...  1.000000e+10
# 9   [stablecoin, asset-backed-stablecoin, binance-...           NaN
# 10  [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 11  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 12        [mineable, pow, scrypt, medium-of-exchange]  8.400000e+07
# 13      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
# 14                  [media, payments, tron-ecosystem]           NaN
#
#     circulating_supply  total_supply  ...  quote.USD.market_cap_dominance  \
# 0         1.930619e+07  1.930619e+07  ...                         42.3770
# 1         1.223739e+08  1.223739e+08  ...                         18.7493
# 2         7.106281e+10  7.314177e+10  ...                          6.6990
# 3         1.578948e+08  1.599800e+08  ...                          4.4246
# 4         4.293257e+10  4.293257e+10  ...                          4.0484
# 5         5.095091e+10  9.998911e+10  ...                          1.8032
# 6         3.467096e+10  3.553818e+10  ...                          1.1339
# 7         1.326708e+11  1.326708e+11  ...                          1.0009
# 8         8.734317e+09  1.000000e+10  ...                          0.9848
# 9         1.008653e+10  1.008653e+10  ...                          0.9511
# 10        3.788521e+08  5.393127e+08  ...                          0.7778
# 11        1.162447e+09  1.288871e+09  ...                          0.6877
# 12        7.239419e+07  8.400000e+07  ...                          0.6437
# 13        5.490633e+14  5.897350e+14  ...                          0.6131
# 14        9.140639e+10  9.140646e+10  ...                          0.5961
#
#     quote.USD.fully_diluted_market_cap  quote.USD.tvl  \
# 0                         4.890028e+11           None
# 1                         1.989042e+11           None
# 2                         7.314726e+10           None
# 3                         4.755872e+10           None
# 4                         4.294460e+10           None
# 5                         3.754552e+10           None
# 6                         1.561379e+10           None
# 7                         1.061854e+10           None
# 8                         1.196076e+10           None
# 9                         1.008999e+10           None
# 10                        1.174478e+10           None
# 11                        8.089314e+09           None
# 12                        7.923973e+09           None
# 13                        6.985653e+09           None
# 14                        6.324251e+09           None
#
#       quote.USD.last_updated platform.id platform.name  platform.symbol  \
# 0   2023-03-02T17:13:00.000Z         NaN           NaN              NaN
# 1   2023-03-02T17:13:00.000Z         NaN           NaN              NaN
# 2   2023-03-02T17:13:00.000Z      1027.0      Ethereum              ETH
# 3   2023-03-02T17:13:00.000Z         NaN           NaN              NaN
# 4   2023-03-02T17:13:00.000Z      1027.0      Ethereum              ETH
# 5   2023-03-02T17:13:00.000Z         NaN           NaN              NaN
# 6   2023-03-02T17:13:00.000Z         NaN           NaN              NaN
# 7   2023-03-02T17:13:00.000Z         NaN           NaN              NaN
# 8   2023-03-02T17:13:00.000Z         NaN           NaN              NaN
# 9   2023-03-02T17:13:00.000Z      1839.0           BNB              BNB
# 10  2023-03-02T17:13:00.000Z         NaN           NaN              NaN
# 11  2023-03-02T17:13:00.000Z         NaN           NaN              NaN
# 12  2023-03-02T17:13:00.000Z         NaN           NaN              NaN
# 13  2023-03-02T17:13:00.000Z      1027.0      Ethereum              ETH
# 14  2023-03-02T17:13:00.000Z         NaN           NaN              NaN
#
#     platform.slug                      platform.token_address  \
# 0             NaN                                         NaN
# 1             NaN                                         NaN
# 2        ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3             NaN                                         NaN
# 4        ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 5             NaN                                         NaN
# 6             NaN                                         NaN
# 7             NaN                                         NaN
# 8             NaN                                         NaN
# 9             bnb                                    BUSD-BD1
# 10            NaN                                         NaN
# 11            NaN                                         NaN
# 12            NaN                                         NaN
# 13       ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 14            NaN                                         NaN
#
#                     timestamp
# 0  2023-03-02 17:47:35.481174
# 1  2023-03-02 17:47:35.481174
# 2  2023-03-02 17:47:35.481174
# 3  2023-03-02 17:47:35.481174
# 4  2023-03-02 17:47:35.481174
# 5  2023-03-02 17:47:35.481174
# 6  2023-03-02 17:47:35.481174
# 7  2023-03-02 17:47:35.481174
# 8  2023-03-02 17:47:35.481174
# 9  2023-03-02 17:47:35.481174
# 10 2023-03-02 17:47:35.481174
# 11 2023-03-02 17:47:35.481174
# 12 2023-03-02 17:47:35.481174
# 13 2023-03-02 17:47:35.481174
# 14 2023-03-02 17:47:35.481174
#
# [15 rows x 36 columns]

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '4f1dc377-a014-4588-96ac-ba7d3d03fc01',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    
    df = pd.json_normalize(data['data'])
    df['timestamp'] = pd.to_datetime('now')
    
    if not os.path.isfile(r'API.csv'):
        df.to_csv(r'API.csv', header = 'column_names')
    else: 
        df.to_csv(r'API.csv', mode = 'a', header = False)

# %%
import os
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60)
exit()
# Out:
# C:\Users\rokzu\AppData\Local\Temp\ipykernel_2596\1968993019.py:25: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp'] = pd.to_datetime('now')
# API Runner completed
# C:\Users\rokzu\AppData\Local\Temp\ipykernel_2596\1968993019.py:25: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp'] = pd.to_datetime('now')
# API Runner completed
# C:\Users\rokzu\AppData\Local\Temp\ipykernel_2596\1968993019.py:25: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp'] = pd.to_datetime('now')
# API Runner completed
# C:\Users\rokzu\AppData\Local\Temp\ipykernel_2596\1968993019.py:25: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp'] = pd.to_datetime('now')
# API Runner completed
# C:\Users\rokzu\AppData\Local\Temp\ipykernel_2596\1968993019.py:25: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp'] = pd.to_datetime('now')
# API Runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[65], line 8
#       6     api_runner()
#       7     print('API Runner completed')
# ----> 8     sleep(60)
#       9 exit()
#
# KeyboardInterrupt:

# %%
df = pd.read_csv(r'API.csv')
df
# Out:
#      Unnamed: 0    id       name symbol          slug  num_market_pairs  \
# 0             0     1    Bitcoin    BTC       bitcoin              9995
# 1             1  1027   Ethereum    ETH      ethereum              6516
# 2             2   825     Tether   USDT        tether             48675
# 3             3  1839        BNB    BNB           bnb              1204
# 4             4  3408   USD Coin   USDC      usd-coin             10413
# ..          ...   ...        ...    ...           ...               ...
# 100          10  5426     Solana    SOL        solana               436
# 101          11  6636   Polkadot    DOT  polkadot-new               475
# 102          12     2   Litecoin    LTC      litecoin               880
# 103          13  5994  Shiba Inu   SHIB     shiba-inu               490
# 104          14  1958       TRON    TRX          tron               731
#
#                    date_added  \
# 0    2013-04-28T00:00:00.000Z
# 1    2015-08-07T00:00:00.000Z
# 2    2015-02-25T00:00:00.000Z
# 3    2017-07-25T00:00:00.000Z
# 4    2018-10-08T00:00:00.000Z
# ..                        ...
# 100  2020-04-10T00:00:00.000Z
# 101  2020-08-19T00:00:00.000Z
# 102  2013-04-28T00:00:00.000Z
# 103  2020-08-01T00:00:00.000Z
# 104  2017-09-13T00:00:00.000Z
#
#                                                   tags     max_supply  \
# 0    ['mineable', 'pow', 'sha-256', 'store-of-value... 21000000.00000
# 1    ['pos', 'smart-contracts', 'ethereum-ecosystem...            NaN
# 2    ['payments', 'stablecoin', 'asset-backed-stabl...            NaN
# 3    ['marketplace', 'centralized-exchange', 'payme...            NaN
# 4    ['medium-of-exchange', 'stablecoin', 'asset-ba...            NaN
# ..                                                 ...            ...
# 100  ['pos', 'platform', 'solana-ecosystem', 'cms-h...            NaN
# 101  ['substrate', 'polkadot', 'binance-chain', 'po...            NaN
# 102  ['mineable', 'pow', 'scrypt', 'medium-of-excha... 84000000.00000
# 103  ['memes', 'ethereum-ecosystem', 'doggone-dogge...            NaN
# 104            ['media', 'payments', 'tron-ecosystem']            NaN
#
#        circulating_supply          total_supply  platform  cmc_rank  \
# 0          19306187.00000        19306187.00000       NaN         1
# 1         122373866.21780       122373866.21780       NaN         2
# 2       71062808809.48134     73141766321.23428       NaN         3
# 3         157894817.26532       159979963.59043       NaN         4
# 4       42932567659.56862     42932567659.56862       NaN         5
# ..                    ...                   ...       ...       ...
# 100       378851963.49476       539312704.88753       NaN        11
# 101      1162502055.65079      1288925725.95597       NaN        12
# 102        72394814.83883        84000000.00000       NaN        13
# 103 549063278876301.93750 589735030408322.75000       NaN        14
# 104     91405023472.94620     91405050349.77472       NaN        15
#
#      self_reported_circulating_supply  self_reported_market_cap  tvl_ratio  \
# 0                                 NaN                       NaN        NaN
# 1                                 NaN                       NaN        NaN
# 2                                 NaN                       NaN        NaN
# 3                                 NaN                       NaN        NaN
# 4                                 NaN                       NaN        NaN
# ..                                ...                       ...        ...
# 100                               NaN                       NaN        NaN
# 101                   904869778.00000          5705148134.55488        NaN
# 102                               NaN                       NaN        NaN
# 103                               NaN                       NaN        NaN
# 104                 71659659264.00000          4981830918.67796        NaN
#
#                  last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0    2023-03-02T17:45:00.000Z      23271.64470     21040235374.06564
# 1    2023-03-02T17:45:00.000Z       1625.29360      7036372061.29554
# 2    2023-03-02T17:45:00.000Z          1.00008     29715026565.01321
# 3    2023-03-02T17:45:00.000Z        297.34997       370351983.51455
# 4    2023-03-02T17:45:00.000Z          1.00025      3568207954.39359
# ..                        ...              ...                   ...
# 100  2023-03-02T19:17:00.000Z         22.03780       333790472.68753
# 101  2023-03-02T19:17:00.000Z          6.30494       220829645.39281
# 102  2023-03-02T19:17:00.000Z         94.84273       465148894.41951
# 103  2023-03-02T19:17:00.000Z          0.00001       191816277.14881
# 104  2023-03-02T19:17:00.000Z          0.06952       212927981.06628
#
#      quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                      -16.53700                     -0.08604
# 1                      -12.83300                      0.08109
# 2                      -15.55880                     -0.00262
# 3                       -5.32040                      0.06981
# 4                       -5.00000                      0.03109
# ..                           ...                          ...
# 100                    -11.31020                      0.96400
# 101                    -18.19100                      0.61692
# 102                    -15.79300                      0.37322
# 103                      8.29010                      1.08271
# 104                     -0.87090                      0.29656
#
#      quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                        -1.95823                     -2.70625
# 1                        -1.97135                     -1.93095
# 2                        -0.00995                     -0.00344
# 3                        -1.80849                     -3.75315
# 4                         0.01918                      0.01611
# ..                            ...                          ...
# 100                      -1.42198                     -7.67368
# 101                      -2.14173                    -11.45485
# 102                      -2.66189                      0.22741
# 103                      -1.81037                     -8.95056
# 104                      -0.92080                     -0.34884
#
#      quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                         0.43171                      40.30699
# 1                         1.91287                      35.37455
# 2                        -0.00092                       0.04206
# 3                        -4.80630                      21.29568
# 4                         0.00591                       0.01326
# ..                            ...                           ...
# 100                      -8.74394                     120.22630
# 101                       0.26665                      44.25609
# 102                       0.30663                      33.42055
# 103                       0.82005                      47.87383
# 104                      11.57745                      26.61947
#
#      quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                        37.27963    449286724364.28101
# 1                        26.89171    198893461014.24460
# 2                         0.00172     71068628210.35786
# 3                         2.47091     46950018951.19566
# 4                         0.02130     42943302223.86349
# ..                            ...                   ...
# 100                      61.84923      8349064128.38556
# 101                      12.38119      7329503753.42551
# 102                      23.62011      6866121671.65339
# 103                      29.83401      6586409535.70861
# 104                      28.11096      6354542803.25851
#
#      quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          42.33090                  488704538687.52002
# 1                          18.73930                  198893461014.23999
# 2                           6.69730                   73147755969.92000
# 3                           4.42350                   47570037145.43000
# 4                           4.04910                   42943302223.86000
# ..                              ...                                 ...
# 100                         0.78080                   11885265993.67000
# 101                         0.68580                    8126597196.42000
# 102                         0.64240                    7966789081.55000
# 103                         0.61590                    7074296492.33000
# 104                         0.59420                    6354544671.75000
#
#      quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0              NaN  2023-03-02T17:45:00.000Z          NaN           NaN
# 1              NaN  2023-03-02T17:45:00.000Z          NaN           NaN
# 2              NaN  2023-03-02T17:45:00.000Z   1027.00000      Ethereum
# 3              NaN  2023-03-02T17:45:00.000Z          NaN           NaN
# 4              NaN  2023-03-02T17:45:00.000Z   1027.00000      Ethereum
# ..             ...                       ...          ...           ...
# 100            NaN  2023-03-02T19:17:00.000Z          NaN           NaN
# 101            NaN  2023-03-02T19:17:00.000Z          NaN           NaN
# 102            NaN  2023-03-02T19:17:00.000Z          NaN           NaN
# 103            NaN  2023-03-02T19:17:00.000Z   1027.00000      Ethereum
# 104            NaN  2023-03-02T19:17:00.000Z          NaN           NaN
#
#     platform.symbol platform.slug                      platform.token_address  \
# 0               NaN           NaN                                         NaN
# 1               NaN           NaN                                         NaN
# 2               ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3               NaN           NaN                                         NaN
# 4               ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# ..              ...           ...                                         ...
# 100             NaN           NaN                                         NaN
# 101             NaN           NaN                                         NaN
# 102             NaN           NaN                                         NaN
# 103             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 104             NaN           NaN                                         NaN
#
#                       timestamp
# 0    2023-03-02 17:47:54.683718
# 1    2023-03-02 17:47:54.683718
# 2    2023-03-02 17:47:54.683718
# 3    2023-03-02 17:47:54.683718
# 4    2023-03-02 17:47:54.683718
# ..                          ...
# 100  2023-03-02 19:18:37.620627
# 101  2023-03-02 19:18:37.620627
# 102  2023-03-02 19:18:37.620627
# 103  2023-03-02 19:18:37.620627
# 104  2023-03-02 19:18:37.620627
#
# [105 rows x 37 columns]

# %%
pd.options.display.max_columns = None
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h', 'quote.USD.percent_change_24h', 'quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d', 'quote.USD.percent_change_90d']].mean()
df3
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                          0.48103                      -1.20421
# Ethereum                         0.71842                      -1.12874
# Tether                           0.00115                      -0.00225
# BNB                              0.44975                      -1.22808
# USD Coin                         0.00612                       0.02826
# XRP                              0.65526                      -1.29608
# Cardano                          0.46394                      -3.41049
# Dogecoin                         0.45126                      -1.62663
# Polygon                          1.21390                      -1.42174
# Binance USD                      0.01379                       0.00725
# Solana                           0.88803                      -1.86292
# Polkadot                         0.59918                      -2.26988
# Litecoin                         0.40461                      -2.78928
# Shiba Inu                        0.98870                      -2.15753
# TRON                             0.28527                      -0.95285
#
#              quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# name
# Bitcoin                         -2.21597                       1.04755
# Ethereum                        -0.91989                       2.68248
# Tether                          -0.00240                      -0.00148
# BNB                             -3.30937                      -4.46952
# USD Coin                         0.01664                       0.02702
# XRP                             -2.90468                      -7.04072
# Cardano                         -9.09915                     -10.50036
# Dogecoin                        -4.65179                     -15.26119
# Polygon                        -10.32514                       8.33488
# Binance USD                      0.00614                       0.00380
# Solana                          -7.83695                      -9.04618
# Polkadot                       -11.51235                       0.21569
# Litecoin                         0.16720                       0.23178
# Shiba Inu                       -8.75000                       0.53513
# TRON                            -0.44577                      11.36473
#
#              quote.USD.percent_change_60d  quote.USD.percent_change_90d
# name
# Bitcoin                          40.98161                      38.07356
# Ethereum                         36.17140                      27.72034
# Tether                            0.04821                       0.00351
# BNB                              21.91265                       3.10630
# USD Coin                          0.02064                       0.02758
# XRP                              11.45867                      -3.12638
# Cardano                          40.01123                       9.57376
# Dogecoin                         14.68011                     -18.52533
# Polygon                          59.51607                      31.92054
# Binance USD                      -0.00147                       0.01561
# Solana                          120.41179                      61.57352
# Polkadot                         44.40496                      12.40734
# Litecoin                         33.40489                      23.58964
# Shiba Inu                        47.68214                      29.59687
# TRON                             26.56886                      28.07329

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin  quote.USD.percent_change_1h     0.48103
#          quote.USD.percent_change_24h   -1.20421
#          quote.USD.percent_change_7d    -2.21597
#          quote.USD.percent_change_30d    1.04755
#          quote.USD.percent_change_60d   40.98161
#                                           ...
# TRON     quote.USD.percent_change_24h   -0.95285
#          quote.USD.percent_change_7d    -0.44577
#          quote.USD.percent_change_30d   11.36473
#          quote.USD.percent_change_60d   26.56886
#          quote.USD.percent_change_90d   28.07329
# Length: 90, dtype: float64

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                        values
# name
# Bitcoin quote.USD.percent_change_1h   0.48103
#         quote.USD.percent_change_24h -1.20421
#         quote.USD.percent_change_7d  -2.21597
#         quote.USD.percent_change_30d  1.04755
#         quote.USD.percent_change_60d 40.98161
# ...                                       ...
# TRON    quote.USD.percent_change_24h -0.95285
#         quote.USD.percent_change_7d  -0.44577
#         quote.USD.percent_change_30d 11.36473
#         quote.USD.percent_change_60d 26.56886
#         quote.USD.percent_change_90d 28.07329
#
# [90 rows x 1 columns]

# %%
type(df5)
# Out:
# pandas.core.frame.DataFrame

# %%
index = pd.Index(range(90))
df6 = df5.reset_index()
df6
# Out:
#        name                       level_1   values
# 0   Bitcoin   quote.USD.percent_change_1h  0.48103
# 1   Bitcoin  quote.USD.percent_change_24h -1.20421
# 2   Bitcoin   quote.USD.percent_change_7d -2.21597
# 3   Bitcoin  quote.USD.percent_change_30d  1.04755
# 4   Bitcoin  quote.USD.percent_change_60d 40.98161
# ..      ...                           ...      ...
# 85     TRON  quote.USD.percent_change_24h -0.95285
# 86     TRON   quote.USD.percent_change_7d -0.44577
# 87     TRON  quote.USD.percent_change_30d 11.36473
# 88     TRON  quote.USD.percent_change_60d 26.56886
# 89     TRON  quote.USD.percent_change_90d 28.07329
#
# [90 rows x 3 columns]

# %%
df7 = df6.rename(columns = {'level_1': 'percent_change'})
df7
# Out:
#        name                percent_change   values
# 0   Bitcoin   quote.USD.percent_change_1h  0.48103
# 1   Bitcoin  quote.USD.percent_change_24h -1.20421
# 2   Bitcoin   quote.USD.percent_change_7d -2.21597
# 3   Bitcoin  quote.USD.percent_change_30d  1.04755
# 4   Bitcoin  quote.USD.percent_change_60d 40.98161
# ..      ...                           ...      ...
# 85     TRON  quote.USD.percent_change_24h -0.95285
# 86     TRON   quote.USD.percent_change_7d -0.44577
# 87     TRON  quote.USD.percent_change_30d 11.36473
# 88     TRON  quote.USD.percent_change_60d 26.56886
# 89     TRON  quote.USD.percent_change_90d 28.07329
#
# [90 rows x 3 columns]

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['1h','24h','7d','30d','60d','90d'])
df7
# Out:
#        name percent_change   values
# 0   Bitcoin             1h  0.48103
# 1   Bitcoin            24h -1.20421
# 2   Bitcoin             7d -2.21597
# 3   Bitcoin            30d  1.04755
# 4   Bitcoin            60d 40.98161
# ..      ...            ...      ...
# 85     TRON            24h -0.95285
# 86     TRON             7d -0.44577
# 87     TRON            30d 11.36473
# 88     TRON            60d 26.56886
# 89     TRON            90d 28.07329
#
# [90 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x = 'percent_change', y = 'values', hue='name', data=df7, kind='point')

# %%
df10 = df[['name','quote.USD.price','timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10
# Out:
#        name  quote.USD.price                   timestamp
# 0   Bitcoin      23271.64470  2023-03-02 17:47:54.683718
# 15  Bitcoin      23271.79275  2023-03-02 17:48:55.097348
# 30  Bitcoin      23487.49064  2023-03-02 19:14:34.071150
# 45  Bitcoin      23476.69761  2023-03-02 19:15:34.442094
# 60  Bitcoin      23464.09136  2023-03-02 19:16:35.080521
# 75  Bitcoin      23438.27407  2023-03-02 19:17:35.582252
# 90  Bitcoin      23432.34705  2023-03-02 19:18:37.620627

# %%
sns.lineplot(x='timestamp',y='quote.USD.price', data=df10)
# Out:
# <AxesSubplot: xlabel='timestamp', ylabel='quote.USD.price'>
